# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/medical_insurance.csv')
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %% [markdown]
# ## DATA PREPROCESSING

# %%
df.shape
# Out:
# (2772, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2772 non-null   int64
#  1   sex       2772 non-null   object
#  2   bmi       2772 non-null   float64
#  3   children  2772 non-null   int64
#  4   smoker    2772 non-null   object
#  5   region    2772 non-null   object
#  6   charges   2772 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 151.7+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  2772.000000  2772.000000  2772.000000   2772.000000
# mean     39.109668    30.701349     1.101732  13261.369959
# std      14.081459     6.129449     1.214806  12151.768945
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    26.220000     0.000000   4687.797000
# 50%      39.000000    30.447500     1.000000   9333.014350
# 75%      51.000000    34.770000     2.000000  16577.779500
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#value count for categorical variables
print(df.sex.value_counts(),'\n',df.smoker.value_counts(),'\n',df.region.value_counts())
# Out:
# sex
# male      1406
# female    1366
# Name: count, dtype: int64
#  smoker
# no     2208
# yes     564
# Name: count, dtype: int64
#  region
# southeast    766
# southwest    684
# northwest    664
# northeast    658
# Name: count, dtype: int64

# %%
df['sex']=df['sex'].map({'male':1,'female':0})
df['smoker']=df['smoker'].map({'yes':1,'no':0})
df['region']=df['region'].map({'southeast':0,'southwest':1,'northwest':2,'northeast':3})

# %%
df.head(10)
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       1  16884.92400
# 1   18    1  33.770         1       0       0   1725.55230
# 2   28    1  33.000         3       0       0   4449.46200
# 3   33    1  22.705         0       0       2  21984.47061
# 4   32    1  28.880         0       0       2   3866.85520
# 5   31    0  25.740         0       0       0   3756.62160
# 6   46    0  33.440         1       0       0   8240.58960
# 7   37    0  27.740         3       0       2   7281.50560
# 8   37    1  29.830         2       0       3   6406.41070
# 9   60    0  25.840         0       0       2  28923.13692

# %% [markdown]
# ## EDA

# %%
#AGE DISTRIBUTION

# %%
sns.histplot(df.age,bins=20,kde=False,color='yellow')
plt.title('AGE DISTRIBUTION')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#GENDER PLOT

# %%
sns.countplot(x='sex',data=df,palette='Set1')
plt.title('GENDER PLOT')
plt.show()
# Out:
# /tmp/ipython-input-13-1406140064.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=df,palette='Set1')

# %% [markdown]
# Males are slightly greater than women in the dataset

# %%
#BMI DISTRIBUTION

# %%
sns.histplot(df.bmi,bins=20,kde=True,color='green')
plt.title('BMI DISTRIBUTION')
# Out:
# Text(0.5, 1.0, 'BMI DISTRIBUTION')

# %% [markdown]
# The majority of the patients have BMI between 25 and 40 which is considered as overweight and could be a major factor in increasing the medical cost.

# %%
#CHILD COUNT DISTRIBUTION

# %%
sns.countplot(x='children',data=df,palette='Set3')
plt.title('CHILD COUNT DISTRIBUTION')
# Out:
# /tmp/ipython-input-17-3125901217.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='children',data=df,palette='Set3')
# Text(0.5, 1.0, 'CHILD COUNT DISTRIBUTION')

# %% [markdown]
# The graph clearly shows that most of the patients have no children and very few patients have more than 3 children.

# %%
#region wise plot

# %%
sns.countplot(x='region',data=df,palette='Set1')
plt.title('REGION WISE PLOT')
# Out:
# /tmp/ipython-input-19-1194342860.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='region',data=df,palette='Set1')
# Text(0.5, 1.0, 'REGION WISE PLOT')

# %% [markdown]
# The count of patient from southeast is slighltly higher than the other regions, but the number of patients from other regions are almost equal.

# %%
#count number of smokers

# %%
sns.countplot(x='smoker',data=df,palette='Set1')
plt.title('COUNT NUMBER OF SMOKERS')
# Out:
# /tmp/ipython-input-21-2045840945.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='smoker',data=df,palette='Set1')
# Text(0.5, 1.0, 'COUNT NUMBER OF SMOKERS')

# %% [markdown]
# smokers are very few in the dataset. Nearly 80% of the patients are non-smokers.

# %%
#Smoker count with respect to the children count.

# %%
sns.countplot(x=df.smoker,hue=df.children)
plt.title('SMOKER COUNT WITH RESPECT TO THE CHILDREN COUNT')
# Out:
# Text(0.5, 1.0, 'SMOKER COUNT WITH RESPECT TO THE CHILDREN COUNT')

# %%
#CHARGE DISTRIBUTION

# %%
sns.histplot(df.charges,bins=20,kde=True,color='red')
plt.title('CHARGE DISTRIBUTION')
# Out:
# Text(0.5, 1.0, 'CHARGE DISTRIBUTION')

# %% [markdown]
# Most of the medical expenses are below 20000, with negligible number of patients having medical expenses above 50000.

# %% [markdown]
# Coorelation

# %%
#CORRELATION MATRIX
df.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.026046  0.113048  0.037574 -0.023286  0.009601  0.298624
# sex      -0.026046  1.000000  0.042924  0.016020  0.082326 -0.015191  0.062837
# bmi       0.113048  0.042924  1.000000 -0.001492  0.011489 -0.270759  0.199846
# children  0.037574  0.016020 -0.001492  1.000000  0.006362  0.005921  0.066442
# smoker   -0.023286  0.082326  0.011489  0.006362  1.000000 -0.038912  0.788783
# region    0.009601 -0.015191 -0.270759  0.005921 -0.038912  1.000000 -0.036496
# charges   0.298624  0.062837  0.199846  0.066442  0.788783 -0.036496  1.000000

# %%
#plotting coorelation heatmap
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# The variable smoker shows a significant coorelation with the medical expenses.Now I will explore more into patients' smoking habits and their relationa with other factors.

# %%
#Plotting the smoker count with patient's gender

# %%
sns.countplot(x=df.smoker,hue=df.sex)
plt.title('SMOKER COUNT WITH PATIENT\'S GENDER')
# Out:
# Text(0.5, 1.0, "SMOKER COUNT WITH PATIENT'S GENDER")

# %% [markdown]
# We can notice more male smokers than female smokers. So, I will assume that medical treatment expense for males would be more than females, given the impact of smoking on the medical expenses.

# %%
sns.violinplot(x='sex',y='charges',data=df,palette='Set1')
# Out:
# /tmp/ipython-input-30-1809056243.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='sex',y='charges',data=df,palette='Set1')
# <Axes: xlabel='sex', ylabel='charges'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(y='smoker',x='charges',data=df[(df.sex==0)],orient='h')
plt.title('Box plot for charges of women')
# Out:
# Text(0.5, 1.0, 'Box plot for charges of women')

# %%
plt.figure(figsize=(10,10))
sns.boxplot(y='smoker',x='charges',data=df[(df.sex==1)],orient='h')
plt.title('Box plot for charges of men')
# Out:
# Text(0.5, 1.0, 'Box plot for charges of men')

# %% [markdown]
# The assumption is true, that the medical expense of males is greater than that of females. In addition to that medical expense of smokers is greater than that of non-smokers.

# %%
#Smokers and age distribution

# %%
sns.catplot(x='smoker',y='age',data=df,kind='swarm',palette='Set1')
# Out:
# /tmp/ipython-input-34-2576163036.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='smoker',y='age',data=df,kind='swarm',palette='Set1')
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 12.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 51.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# From the graph, we can see that there significant number of smokers of age 19. Now I will study the medical expense of smokers of age 19.

# %%
##smokers of age 19
plt.figure(figsize=(12,5))
sns.boxplot(y='smoker',x='charges',data=df[(df.age==19)],orient='h')

plt.title("Box plot for charges of smokers of age 19")
plt.xlabel('Medical Expense')
plt.ylabel('Smoker')
plt.show()

# %% [markdown]
# Surprisingly the medical expense of smokers of age 19 is very high in comparison to non smokers. In non smokers we can see some outliners, which may be due to illness or accidents
#
# It is clear that the medical expense of smokers is higher than that of non-smokers. Now I will plot the charges distribution with repect to patients age of smokers and non-smokers.

# %%
##non smokers charge distribution
plt.figure(figsize=(7,5))
plt.title("scatterplot for charges of non smokers")
sns.scatterplot(x='age',y='charges',data=df[(df.smoker==0)])
# Out:
# <Axes: title={'center': 'scatterplot for charges of non smokers'}, xlabel='age', ylabel='charges'>

# %% [markdown]
# Majority of the points shows that medical expense increases with age which may be due to the fact that older people are more prone to illness. But there are some outliners which shows that there are other illness or accidents which may increase the medical expense.

# %%
#smokers charge distribution
plt.figure(figsize=(7,5))
plt.title("scatterplot for charges of smokers")
sns.scatterplot(x='age',y='charges',data=df[(df.smoker==1)])
# Out:
# <Axes: title={'center': 'scatterplot for charges of smokers'}, xlabel='age', ylabel='charges'>

# %% [markdown]
# Here we see pecularity in the graph. In the graph there are two segments, one with high medical expense which may be due to smoking related illness and the other with low medical expense which may be due age related illness.
#
# Now, in order to get a more clear picture, I will combine these two graphs.

# %%
#age charges distribution
sns.lmplot(x='age',y='charges',data=df,hue='smoker',palette='Set1')

# %% [markdown]
# Now, we clearly understand the variation in charges with respect to age and smoking habits. The medical expense of smokers is higher than that of non-smokers. In non-smokers, the cost of treatment increases with age which is obvious. But in smokers, the cost of treatment is high even for younger patients, which means the smoking patients are spending upon their smoking related illness as well as age related illness.

# %%
#Charges distribution for patients with BMI greater than 30 i.e. obese patient
plt.figure(figsize=(10,10))
sns.distplot(df[(df.bmi>=30)]['charges'])
plt.title('Charges distribution for patients with BMI greater than 30 i.e. obese patient')
# Out:
# /tmp/ipython-input-39-376034664.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[(df.bmi>=30)]['charges'])
# Text(0.5, 1.0, 'Charges distribution for patients with BMI greater than 30 i.e. obese patient')

# %%
#Charges distribution for patients with BMI less than 30 i.e. healthy patients

plt.figure(figsize=(10,10))
sns.distplot(df[(df.bmi<30)]['charges'])
plt.title('Charges distribution for patients with BMI less than 30 i.e. obese patient')
# Out:
# /tmp/ipython-input-40-3861554015.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[(df.bmi<30)]['charges'])
# Text(0.5, 1.0, 'Charges distribution for patients with BMI less than 30 i.e. obese patient')

# %% [markdown]
# Therefore, patients with BMI less than 30 are spending less on medical treatment than those with BMI greater than 30

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop('charges',axis=1),df['charges'],test_size=0.2,random_state=0)

# %% [markdown]
# Model Building

# %% [markdown]
# Linear Regression

# %%
#linear regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr
# Out:
# LinearRegression()

# %%
#model training
lr.fit(x_train,y_train)
#model accuracy
lr.score(x_train,y_train)
# Out:
# 0.751608547578011

# %%
#model prediction
y_pred=lr.predict(x_test)

# %% [markdown]
# Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=2)
poly_reg
# Out:
# PolynomialFeatures()

# %%
#transforming features to higher degree
x_train_poly=poly_reg.fit_transform(x_train)
#splitting data
x_train,x_test,y_train,y_test=train_test_split(x_train_poly,y_train,test_size=0.2,random_state=0)

# %%
plr=LinearRegression()
#model training
plr.fit(x_train,y_train)
#model accuracy
plr.score(x_train,y_train)
# Out:
# 0.8524301267959518

# %%
#modelprediction
y_pred=plr.predict(x_test)

# %% [markdown]
# Decision Tree Regressor

# %%
#decision tree regressor
from sklearn.tree import DecisionTreeRegressor
dtree=DecisionTreeRegressor()
dtree
# Out:
# DecisionTreeRegressor()

# %%
#model training
dtree.fit(x_train,y_train)
#model accuracy
dtree.score(x_train,y_train)
# Out:
# 0.9984914855703526

# %%
dtree_pred=dtree.predict(x_test)

# %% [markdown]
# Random Forest Regressor

# %%
#random forest regressor
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf
# Out:
# RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
# Out:
# 0.9884970085264706

# %%
rf_pred=rf.predict(x_test)

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,root_mean_squared_error

# %% [markdown]
# Linear Regression

# %%
plt.figure(figsize=(10,10))
ax1=sns.distplot(y_test,hist=False,color='green',label='Actual Value')
sns.distplot(y_pred,hist=False,color='red',label='Predicted Value',ax=ax1)
plt.title('Actual vs Predicted Values for Linear Regression')
plt.xlabel('Medical Expense')
plt.show()
# Out:
# /tmp/ipython-input-59-2475201387.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(y_test,hist=False,color='green',label='Actual Value')
# /tmp/ipython-input-59-2475201387.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred,hist=False,color='red',label='Predicted Value',ax=ax1)

# %%
print('MAE:',mean_absolute_error(y_test,y_pred))
print('MSE:',mean_squared_error(y_test,y_pred))
print('RMSE:',root_mean_squared_error(y_test,y_pred))
print('R2SCORE:',r2_score(y_test,y_pred))
# Out:
# MAE: 2890.827675906163
# MSE: 24098382.679881733
# RMSE: 4909.010356465113
# R2SCORE: 0.8237223622293276

# %% [markdown]
# Polynomial Regression

# %%
plt.figure(figsize=(10,10))
ax1=sns.distplot(y_test,hist=False,color='green',label='Actual Value')
sns.distplot(y_pred,hist=False,color='red',label='Predicted Value',ax=ax1)
plt.title('Actual vs Predicted Values for Polynomial Regression')
plt.xlabel('Medical Expense')
plt.show()
# Out:
# /tmp/ipython-input-63-575291842.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(y_test,hist=False,color='green',label='Actual Value')
# /tmp/ipython-input-63-575291842.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred,hist=False,color='red',label='Predicted Value',ax=ax1)

# %%
print('MAE:',mean_absolute_error(y_test,y_pred))
print('MSE:',mean_squared_error(y_test,y_pred))
print('RMSE:',root_mean_squared_error(y_test,y_pred))
print('R2SCORE:',r2_score(y_test,y_pred))
# Out:
# MAE: 2890.827675906163
# MSE: 24098382.679881733
# RMSE: 4909.010356465113
# R2SCORE: 0.8237223622293276

# %% [markdown]
# Decision Tree Regressor

# %%
plt.figure(figsize=(10,10))
ax=sns.distplot(y_test,hist=False,color='green',label='Actual Value')
sns.distplot(dtree_pred,hist=False,color='red',label='Fitted Value',ax=ax)
plt.title('Actual vs Fitted Values for Decision Tree Regression')
plt.xlabel('Medical Expense')
plt.show()
# Out:
# /tmp/ipython-input-69-3853090478.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(y_test,hist=False,color='green',label='Actual Value')
# /tmp/ipython-input-69-3853090478.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dtree_pred,hist=False,color='red',label='Fitted Value',ax=ax)

# %%
print('MAE:',mean_absolute_error(y_test,dtree_pred))
print('MSE:',mean_squared_error(y_test,dtree_pred))
print('RMSE:',root_mean_squared_error(y_test,dtree_pred))
print('R2SCORE:',r2_score(y_test,dtree_pred))
# Out:
# MAE: 1118.6990870195198
# MSE: 15645218.77649184
# RMSE: 3955.403743803133
# R2SCORE: 0.8855565435672264

# %% [markdown]
# Random Forest Regressor

# %%
plt.figure(figsize=(10,10))
ax=sns.distplot(y_test,hist=False,color='green',label='Actual Value')
sns.distplot(rf_pred,hist=False,color='red',label='Fitted Value',ax=ax)
plt.title('Actual vs Fitted Values for Decision Tree Regression')
plt.xlabel('Medical Expense')
plt.show()
# Out:
# /tmp/ipython-input-71-39086871.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(y_test,hist=False,color='green',label='Actual Value')
# /tmp/ipython-input-71-39086871.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(rf_pred,hist=False,color='red',label='Fitted Value',ax=ax)

# %%
print('MAE:',mean_absolute_error(y_test,rf_pred))
print('MSE:',mean_squared_error(y_test,rf_pred))
print('RMSE:',root_mean_squared_error(y_test,rf_pred))
print('R2SCORE:',r2_score(y_test,rf_pred))
# Out:
# MAE: 1579.9574131371662
# MSE: 12002389.04875392
# RMSE: 3464.4464274619572
# R2SCORE: 0.9122035359291875

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# From the above models,we can see Random Forest Regressor are giving the best results.RMSE value of Random Forest Regressor is the least.Therefore,i will use Random Forest Regressor topredict medical expense of patients.
